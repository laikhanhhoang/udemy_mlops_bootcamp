# %%
import yaml

with open("yaml-basics.yaml", "r") as f:
    data = yaml.safe_load(f)

# %% [markdown]
# Nội dung file **yaml-basics.yaml**:
#
# ```yaml
# YAML:
#   - Y: YAML
#   - A: Ain't
#   - M: Markup
#   - L: Language
# my-course: "AWS DevOps Professional Certification"
# version: 1.0
# price: 299
# is_public: true
# release_date: 2022-01-10
# pre_enroll: null
# category:
#   - AWS
#   - DevOps
#   - AWS Certification
# course_dev: ["murthy","kavya","nirnay"]
# dev_details:
#   - name: "murthy"
#     email: "support@manifoldailearning.in"
#     role: "Author"
#   - {name: "navishka", email: "support@manifoldailearning.in", role: "Finance"}
#     ......
# ```

# %%
data
# Out:
# {'YAML': [{'Y': 'YAML'}, {'A': "Ain't"}, {'M': 'Markup'}, {'L': 'Language'}],
#  'my-course': 'AWS DevOps Professional Certification',
#  'version': 1.0,
#  'price': 299,
#  'is_public': True,
#  'release_date': datetime.date(2022, 1, 10),
#  'pre_enroll': None,
#  'category': ['AWS', 'DevOps', 'AWS Certification'],
#  'course_dev': ['murthy', 'kavya', 'nirnay'],
#  'dev_details': [{'name': 'murthy',
#    'email': 'support@manifoldailearning.in',
#    'role': 'Author'},
#   {'name': 'kavya',
#    'email': 'support@manifoldailearning.in',
#    'role': 'Co-Author'},
#   {'name': 'nirnay',
#    'email': 'support@manifoldailearning.in',
#    'role': 'Editor'},
#   {'name': 'navishka',
#    'email': 'support@manifoldailearning.in',
#    'role': 'Finance'}],
#  'short_description': 'This is a course for  AWS DevOps Professional Certification\n',
# ...
